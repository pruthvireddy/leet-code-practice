# %%
from typing import List
import collections

# %% [markdown]
# ## **136. Single Number**
#
# Given a non-empty array of integers nums, every element appears twice except for one. Find that single one.
#
# Follow up: Could you implement a solution with a linear runtime complexity and without using extra memory?
#
#
# Example 1:
#
# Input: nums = [2,2,1]
# Output: 1

# %%
nums = [2,2,1,1,4,4,5]

# %%
class Solution:
    def singleNumber(self, nums: List[int]) -> int:
        
        no_duplicate_list = []
        for i in nums:
            if i not in no_duplicate_list:
                no_duplicate_list.append(i)
            else:
                no_duplicate_list.remove(i)
        return no_duplicate_list.pop()

# %%
class Solution:
    def singleNumber(self, nums: List[int]) -> int:
        
        hash_table = collections.defaultdict(int)
        for i in nums:
            hash_table[i] += 1
            
        for i in hash_table:
            if hash_table[i] == 1:
                return i

# %%
class Solution:
    def singleNumber(self, nums: List[int]) -> int:
      val = 2*sum(set(nums)) - sum(nums)
      return val

# %%
class Solution(object):
    def singleNumber(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        a = 0
        for i in nums:
            a ^= i
        return a

# %%
ls = Solution()
ls.singleNumber(nums)
# Out:
# 5

# %% [markdown]
# ## 35. Search Insert Position
#
# Given a sorted array of distinct integers and a target value, return the index if the target is found. If not, return the index where it would be if it were inserted in order.
#
# Example 1:
#
# Input: nums = [1,3,5,6], target = 5
# Output: 2
# Example 2:
#
# Input: nums = [1,3,5,6], target = 2
# Output: 1

# %%
nums = [3,4,1,2,6]
nums.sort()

# %%
target = 5

# %%
class Solution:
    def searchInsert(self, nums: List[int], target: int) -> int:
        if target in nums:
            return nums.index(target)
        else:
            nums.append(target)
            nums.sort()
            return nums.index(target)

# %%
def searchInsert(self, nums, target):
        low = 0
        high = len(nums) - 1
        while low <= high:
            mid = (low + high) / 2
            if nums[mid] == target:
                return mid
            elif nums[mid] < target:
                low = mid + 1
            else:
                high = mid - 1
        return low

# %%
class Solution(object):
    def searchInsert(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: int
        """
        return bisect.bisect_left(nums, target)

# %%
class Solution(object):
    def searchInsert(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: int
        """       
        return len([x for x in nums if x<target])

# %% [markdown]
# ## 13. Roman to Integer
#
# Roman numerals are represented by seven different symbols: I, V, X, L, C, D and M.
#
# Symbol       Value
# I             1
# V             5
# X             10
# L             50
# C             100
# D             500
# M             1000
# For example, 2 is written as II in Roman numeral, just two one's added together. 12 is written as XII, which is simply X + II. The number 27 is written as XXVII, which is XX + V + II.
#
# Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not IIII. Instead, the number four is written as IV. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as IX. There are six instances where subtraction is used:
#
# I can be placed before V (5) and X (10) to make 4 and 9.
# X can be placed before L (50) and C (100) to make 40 and 90.
# C can be placed before D (500) and M (1000) to make 400 and 900.
# Given a roman numeral, convert it to an integer.

# %%
class Solution:
  def romanToInt(self, s: str) -> List[int]:
    
    roman_map = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}
    rom_int_map = collections.defaultdict(int)

    for i in range(0, len(s)):
      rom_int_map[i] = roman_map[s[i]]
    val = 0
    for i in list(rom_int_map):
      if rom_int_map[i] < rom_int_map[i+1] and ((rom_int_map[i] < rom_int_map[i-1]) or i == 0): # case to handle IV XC etc
        #val.append(rom_int_map[i+1] - rom_int_map[i])
        val += rom_int_map[i+1] - rom_int_map[i]

      elif rom_int_map[i] > rom_int_map[i-1] and i != 0 : # case to skip the first character from being misunderstood
        continue
      
      else:
        #val.append(rom_int_map[i])
        val += rom_int_map[i]

    return val

# %%
rom = 'IV'
rom = 'MCMXCIV'

ls = Solution()
trial = ls.romanToInt(rom)
trial
# Out:
# 1994

# %% [markdown]
# ## 58. Length of Last Word
#
# Given a string s consists of some words separated by spaces, return the length of the last word in the string. If the last word does not exist, return 0.
#
# A word is a maximal substring consisting of non-space characters only.
#
#
#
# Example 1:
#
# Input: s = "Hello World"
# Output: 5
# Example 2:
#
# Input: s = " "
# Output: 0

# %%
trial = "Hello World! by Pruthvi"

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        s_list = s.split()
        if len(s_list) ==0:
          return 0
        else:
          lw_len = len(s_list[-1])
          return lw_len

# %% [markdown]
# **28 MS**

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        l = s.strip().split()
        if len(l) > 0:
            return len(l[-1])
        else:
            return 0

# %% [markdown]
# **24 MS**

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        mylist = s.split()
        if len(mylist) == 0:
            return 0;
       # print(mylist)
        return len(mylist[-1])

# %%
class Solution:
    def lengthOfLastWord(self, s):
        end = len(s) - 1
        while end > 0 and s[end] == " ": end -= 1
        beg = end
        while beg >= 0 and s[beg] != " ": beg -= 1
        return end - beg

# %% [markdown]
# **12 ms**

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        list1=s.split()
        if len(list1)==0:
            return 0
        #print(list1)
        str1=list1[-1]
        #print(str1)
        return len(str1)

# %% [markdown]
# **8 MS**

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        return len(s.strip().split(' ')[-1])

# %%
trial= " "

# %%
ls = Solution()
trial_out = ls.lengthOfLastWord(trial)
trial_out
# Out:
# 0

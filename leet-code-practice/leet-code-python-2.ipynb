# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
        l1[]

# %%
l1 = [2,4,3]
l2 = [5,6,4]

# %%
n1= len(l1)
n2= len(l1)

# %%
l1_num_str =""
for i in range(len(l1)):
  l1_num_str = l1_num_str+ str(l1[i])

l2_num_str =""
for j in range(len(l2)):
  l2_num_str = l2_num_str+ str(l2[j])

# %%
print(l1_num_str,l2_num_str)
# Out:
# 243 564

# %%
l1_num_str = l1_num_str[::-1]
l2_num_str = l2_num_str[::-1]

sum = int(l1_num_str) + int(l2_num_str)
sum_rev_str = str(sum)[::-1]

# %%
print(sum,sum_rev_str)
# Out:
# 807 708

# %%
len(sum_rev_str)
# Out:
# 3

# %%
print(sum_rev_str[0])
# Out:
# 7

# %%
ret_lst =[]
for j in range(len(sum_rev_str)):
  ret_lst.append(sum_rev_str[j])

# %%
ret_lst
# Out:
# ['7', '0', '8']
